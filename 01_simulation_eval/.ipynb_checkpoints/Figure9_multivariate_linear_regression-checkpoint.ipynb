# %%
import datetime
import cftime
import glob
import h5py
import gc
import copy
import os
import re
import sys
import codecs
import csv
from matplotlib.ticker import FuncFormatter
import geopandas as gpd
import rasterio
from shapely.geometry import mapping
import pandas as pd
import xarray as xr
import numpy as np
import netCDF4 as nc
import rioxarray
from scipy.stats import pearsonr

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import matplotlib.colors as mcolors
import matplotlib.ticker as mticker
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.cm import ScalarMappable
from matplotlib.ticker import FormatStrFormatter
from matplotlib.patches import Rectangle

import cartopy
from cartopy import crs as ccrs
from cartopy import feature as cfeature

from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset

# %%
import os
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"

# %%
data_path='/glade/work/yifanc17/02_data/05_cesm_simulation/'
plot_path='/glade/work/yifanc17/03_plots/06_Manuscript_plots/JAMES_manuscript/'
surf_path='/glade/work/yifanc17/02_data/cesmdata/surfdata/CONUS_3p75/'
agg_path = '/glade/campaign/univ/uiuc0043/02_USURF/data_conversion/agg_data/'

# %%
def clip_netcdf_by_shp(data,shp,all_touched=False):
    # convert lon to -180~180
    data_lon180=data.copy()
    converted_lon = data_lon180['lon'].where(data_lon180['lon'] <= 180, data_lon180['lon'] - 360)
    data_lon180 = data_lon180.assign_coords(lon=converted_lon)
    data_lon180 = data_lon180.sortby('lon')

    ds = data_lon180.rio.set_spatial_dims(x_dim="lon", y_dim="lat",inplace=True)
    ds = ds.rio.write_crs("EPSG:4326", inplace=True)

    clipped_ds=ds.rio.clip([mapping(shp)], crs=4326,all_touched=all_touched)
    return clipped_ds

# %%
us_shp=gpd.read_file('/glade/work/yifanc17/02_data/02_urban_1km_dataset/boundary_shp/US_bounds.shp')

# %%
us_geom=us_shp.geometry.union_all()

# %% [markdown]
# ### CONUS 3.75km simulation, delta LST

# %%
data_path
# Out:
# '/glade/work/yifanc17/02_data/05_cesm_simulation/'

# %%
ctrl_surf=xr.open_dataset(surf_path+'surfdata_CONUS_1d32deg_hist_2015_16pfts_c250625.nc')
test_surf=xr.open_dataset(surf_path+'surfdata_CONUS_1d32deg_hist_usurf_adjusted_pct_2015_16pfts_TEST_THR_c250405.nc')

# %%
MODIS_SUMM_LST_avg=xr.open_dataset('/glade/campaign/univ/uiuc0056/yifan/MODIS_LST_AT_1km/USurf_masked/nc/AQUA_avg_SUMM_LST_2010_2014_annual_avg_CONUS_1d32deg_USURF_masked_regridded.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /glade/work/yifanc17/miniconda3/envs/geo_xr311/lib/python3.11/site-packages/xarray/backends/file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File /glade/work/yifanc17/miniconda3/envs/geo_xr311/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# ...

# %%
ctrl_annual_avg_1d32deg=xr.open_dataset(data_path+'/Landonly_1d32deg/WFDE5.Regridded.CTSM5.2.015.ExplicitAC.CONUS.1d32deg.CTRL.c250625_2010_2014_5yr_annual_avg.nc')
test_annual_avg_1d32deg=xr.open_dataset(data_path+'/Landonly_1d32deg/WFDE5.Regridded.CTSM5.2.015.ExplicitAC.CONUS.1d32deg.TEST.THR.c250407_2010_2014_5yr_annual_avg.nc')

# %%
def convert_lsmlatlon_to_latlon(ds):
    ds = ds.rename({"lsmlat": "lat", "lsmlon": "lon"})

    lat_new = ctrl_annual_avg_1d32deg.lat.values 
    lon_new = ctrl_annual_avg_1d32deg.lon.values
    
    ds = ds.assign_coords(lat=("lat", lat_new),
                          lon=("lon", lon_new))

    return ds

# %%
ctrl_surf_latlon=convert_lsmlatlon_to_latlon(ctrl_surf)
test_surf_latlon=convert_lsmlatlon_to_latlon(test_surf)

# %%
np.all(test_surf_latlon.lon.values==ctrl_surf_latlon.lon.values)
# Out:
# np.True_

# %%
conus_obs = clip_netcdf_by_shp(MODIS_SUMM_LST_avg.LST,us_geom)
conus_ctrl = clip_netcdf_by_shp(ctrl_annual_avg_1d32deg['TSKIN_U'],us_geom)
conus_test = clip_netcdf_by_shp(test_annual_avg_1d32deg['TSKIN_U'],us_geom)

valid_mask = np.isfinite(conus_ctrl) & np.isfinite(conus_obs) & np.isfinite(conus_test)
conus_obs = conus_obs.where(valid_mask)
conus_ctrl = conus_ctrl.where(valid_mask)
conus_test = conus_test.where(valid_mask)

ctrl = conus_ctrl.values.flatten()
test = conus_test.values.flatten()
obs  = conus_obs.values.flatten()

flat_valid_mask = np.isfinite(ctrl) & np.isfinite(test) & np.isfinite(obs)
conus_ctrl_clean = ctrl[flat_valid_mask]
conus_test_clean = test[flat_valid_mask]
conus_obs_clean  = obs[flat_valid_mask]

ctrl_mae = np.mean(np.abs(conus_ctrl_clean - conus_obs_clean))
test_mae = np.mean(np.abs(conus_test_clean - conus_obs_clean))

# %%
def calc_weighted_average_params(ds,var):
    if 'ALB' in var:
        x = ds[var].sel(numrad=0)
    else:     
        x = ds[var]           
    w = ds["PCT_URBAN"]
    w_sum = w.sum(dim="numurbl")
    var_wa = (x * w).sum(dim="numurbl") / w_sum
    var_wa = var_wa.where(w_sum > 0)
    
    var_wa.name = f"{var}_URBAN_WA"
    return var_wa

# %%
def extract_ucp_diff(var):
    ctrl_var=calc_weighted_average_params(ctrl_surf_latlon,var)
    if 'ALB' in var:
        test_var=test_surf_latlon[var].sel(numurbl=2,numrad=0)
    else:
        test_var=test_surf_latlon[var].sel(numurbl=2)
    ctrl_var=clip_netcdf_by_shp(ctrl_var,us_geom)
    test_var=clip_netcdf_by_shp(test_var,us_geom)
    var_mask= (ctrl_var>0) & (test_var>0)
    ctrl_var=ctrl_var.where(var_mask)
    test_var=test_var.where(var_mask)

    ctrl_var=ctrl_var.values.flatten()
    test_var=test_var.values.flatten()
    ctrl_var_clean=ctrl_var[flat_valid_mask]
    test_var_clean=test_var[flat_valid_mask]

    diff_var=test_var_clean-ctrl_var_clean
    diff_var=diff_var[diff_var!=0]
    return diff_var

# %%
var='TSA_U'
conus_ctrl = clip_netcdf_by_shp(ctrl_annual_avg_1d32deg[var],us_geom)
conus_test = clip_netcdf_by_shp(test_annual_avg_1d32deg[var],us_geom)

valid_mask = np.isfinite(conus_ctrl) & np.isfinite(conus_test)
conus_ctrl = conus_ctrl.where(valid_mask)
conus_test = conus_test.where(valid_mask)

ctrl = conus_ctrl.values.flatten()
test = conus_test.values.flatten()

flat_valid_mask = np.isfinite(ctrl) & np.isfinite(test)

# %%
diff_em_roof=extract_ucp_diff('EM_ROOF')
diff_em_improad=extract_ucp_diff('EM_IMPROAD')
diff_em_perroad=extract_ucp_diff('EM_PERROAD')
diff_em_wall=extract_ucp_diff('EM_WALL')

diff_alb_roof=extract_ucp_diff('ALB_ROOF_DIR')
diff_alb_improad=extract_ucp_diff('ALB_IMPROAD_DIR')
diff_alb_perroad=extract_ucp_diff('ALB_PERROAD_DIR')
diff_alb_wall=extract_ucp_diff('ALB_WALL_DIR')

diff_wt_roof=extract_ucp_diff('WTLUNIT_ROOF')
diff_wt_perv=extract_ucp_diff('WTROAD_PERV')
diff_ht_roof=extract_ucp_diff('HT_ROOF')
diff_hwr=extract_ucp_diff('CANYON_HWR')

# %%
diff_lst=conus_test_clean-conus_ctrl_clean

# %%
datasets=[diff_em_roof,diff_em_improad,diff_em_perroad,diff_em_wall,
          diff_alb_roof,diff_alb_improad,diff_alb_perroad,diff_alb_wall,
         diff_wt_roof,diff_wt_perv,diff_ht_roof,diff_hwr]
dataset_names=['Roof emissivity', 'Impervious emissivity','Pervious emissivity','Wall emissivity',
              'Roof albedo','Impervious albedo','Pervious albedo','Wall albedo',
              'Roof fraction','Pervious fraction','Building height','Canyon H/W']
var_shortnames=['EM_ROOF','EM_IMPROAD','EM_PERROAD','EM_WALL',
               'ALB_ROOF','ALB_IMPROAD','ALB_PERROAD','ALB_WALL',
               'WTLUNIT_ROOF','WTROAD_PERV','HT_ROOF','CANYON_HWR']

# %%
y = np.asarray(diff_lst)

r_vals = []
p_vals = []

for x in datasets:
    x = np.asarray(x)
    m = np.isfinite(x) & np.isfinite(y)
    if m.sum() >= 3:
        r, p = pearsonr(x[m], y[m])
    else:
        r, p = np.nan, np.nan
    r_vals.append(r)
    p_vals.append(p)

R = np.array(r_vals).reshape(1, 12)   # shape (1, 12)
P = np.array(p_vals).reshape(1, 12)

# %% [markdown]
# ## CONUS 3.75km simulation, delta T2M

# %%
param_datasets=[diff_em_roof,diff_em_improad,diff_em_perroad,diff_em_wall,
          diff_alb_roof,diff_alb_improad,diff_alb_perroad,diff_alb_wall,
         diff_wt_roof,diff_wt_perv,diff_ht_roof,diff_hwr]
dataset_names=['Roof emissivity', 'Impervious emissivity','Pervious emissivity','Wall emissivity',
              'Roof albedo','Impervious albedo','Pervious albedo','Wall albedo',
              'Roof fraction','Pervious fraction','Building height','Canyon H/W']
var_shortnames=['EM_ROOF','EM_IMPROAD','EM_PERROAD','EM_WALL',
               'ALB_ROOF','ALB_IMPROAD','ALB_PERROAD','ALB_WALL',
               'WTLUNIT_ROOF','WTROAD_PERV','HT_ROOF','CANYON_HWR']

# %%
def calc_pearson_r(diff_var):
    y = np.asarray(diff_var)

    r_vals = []
    p_vals = []
    
    for x in param_datasets:
        x = np.asarray(x)
        m = np.isfinite(x) & np.isfinite(y)
        if m.sum() >= 3:
            r, p = pearsonr(x[m], y[m])
        else:
            r, p = np.nan, np.nan
        r_vals.append(r)
        p_vals.append(p)
    
    R = np.array(r_vals).reshape(1, 12)  
    P = np.array(p_vals).reshape(1, 12)

    return R,P

# %%
def extract_conus_model_var_diff(var):
    conus_ctrl = clip_netcdf_by_shp(ctrl_annual_avg_1d32deg[var],us_geom)
    conus_test = clip_netcdf_by_shp(test_annual_avg_1d32deg[var],us_geom)
    
    valid_mask = np.isfinite(conus_ctrl) & np.isfinite(conus_test)
    conus_ctrl = conus_ctrl.where(valid_mask)
    conus_test = conus_test.where(valid_mask)
    
    ctrl = conus_ctrl.values.flatten()
    test = conus_test.values.flatten()
    
    flat_valid_mask = np.isfinite(ctrl) & np.isfinite(test)
    conus_ctrl_clean = ctrl[flat_valid_mask]
    conus_test_clean = test[flat_valid_mask]

    diff_var=conus_test_clean-conus_ctrl_clean

    R,P=calc_pearson_r(diff_var)

    return R,P

# %%
meteo_vars=['TSKIN_U','TSA_U','RH2M_U','FSH_U','EFLX_LH_TOT_U','FIRA_U','FSA_U','FIRE_U']
row_names=[rf'$\Delta$ {v}' for v in meteo_vars]

# %%
R_list=[]
P_list=[]
for var in meteo_vars:
    R,P=extract_conus_model_var_diff(var)
    R_list.append(np.asarray(R).reshape(-1))
    P_list.append(np.asarray(P).reshape(-1))

# %%
R = np.asarray(R_list)  # shape (nrow, 12)
P = np.asarray(P_list)  # shape (nrow, 12)

nrow, ncol = R.shape

fig, ax = plt.subplots(figsize=(18, 1.2 * nrow + 1.5))

xx, yy = np.meshgrid(np.arange(ncol), np.arange(nrow))

# bubble size proportional to |r|
smin, smax = 200, 2000
S = smin + (smax - smin) * np.nan_to_num(np.abs(R), nan=0.0)

sc = ax.scatter(
    xx.ravel(), yy.ravel(),
    s=S.ravel(),
    c=R.ravel(),
    cmap="RdYlBu_r",
    vmin=-1, vmax=1,
    edgecolors="k",
    linewidths=0.6
)

# annotate numbers (and significance star)
for i in range(nrow):
    for j in range(ncol):
        r = R[i, j]
        p = P[i, j]
        if np.isfinite(r):
            star = "*" if (np.isfinite(p) and p < 0.05) else ""
            ax.text(j, i, f"{r:+.2f}{star}", ha="center", va="center", fontsize=11)

# formatting
ax.set_xlim(-0.5, ncol - 0.5)
ax.set_ylim(nrow - 0.5, -0.5)  # put first row on top

# y labels for each row
ax.set_yticks(np.arange(nrow))
ax.set_yticklabels(row_names, fontsize=14)

# x labels only on bottom row (set ticks, but hide labels except bottom)
ax.set_xticks(np.arange(ncol))
xticklabels = [rf'$\Delta$ {v}' for v in var_shortnames]
ax.set_xticklabels(xticklabels, rotation=90, fontsize=14)
ax.tick_params(axis="x", labelbottom=True, bottom=True, top=False)

ax.set_xticks(np.arange(-0.5, ncol, 1), minor=True)
ax.set_yticks(np.arange(-0.5, nrow, 1), minor=True)
ax.grid(which="minor", color="0.85", linewidth=1, linestyle='--')
ax.tick_params(which="minor", bottom=False, left=False)

plt.tight_layout()
fig.savefig('Pearson_r_multi_params_conus_all_common_urban_pixels.png', dpi=300, bbox_inches='tight')

# %%
us_clusters_shapefile=gpd.read_file('/glade/work/yifanc17/02_data/02_urban_1km_dataset/boundary_shp/USGS_TIGER_city/tl_2023_us_uac20.shp')
us_clusters_geom=us_clusters_shapefile.union_all()

# %%
def extract_conus_cluster_model_var_diff(var):
    conus_ctrl = clip_netcdf_by_shp(ctrl_annual_avg_1d32deg[var],us_clusters_geom)
    conus_test = clip_netcdf_by_shp(test_annual_avg_1d32deg[var],us_clusters_geom)
    
    valid_mask = np.isfinite(conus_ctrl) & np.isfinite(conus_test)
    conus_ctrl = conus_ctrl.where(valid_mask)
    conus_test = conus_test.where(valid_mask)
    
    ctrl = conus_ctrl.values.flatten()
    test = conus_test.values.flatten()
    
    flat_valid_mask = np.isfinite(ctrl) & np.isfinite(test)
    conus_ctrl_clean = ctrl[flat_valid_mask]
    conus_test_clean = test[flat_valid_mask]

    diff_var=conus_test_clean-conus_ctrl_clean

    R,P=calc_pearson_r(diff_var)

    return R,P

# %%
var='TSA_U'
conus_ctrl = clip_netcdf_by_shp(ctrl_annual_avg_1d32deg[var],us_clusters_geom)
conus_test = clip_netcdf_by_shp(test_annual_avg_1d32deg[var],us_clusters_geom)

valid_mask = np.isfinite(conus_ctrl) & np.isfinite(conus_test)
conus_ctrl = conus_ctrl.where(valid_mask)
conus_test = conus_test.where(valid_mask)

ctrl = conus_ctrl.values.flatten()
test = conus_test.values.flatten()

flat_valid_mask = np.isfinite(ctrl) & np.isfinite(test)

# %%
flat_valid_mask
# Out:
# array([False, False, False, ..., False, False, False], shape=(1418013,))

# %%
def extract_conus_cluster_ucp_diff(var):
    ctrl_var=calc_weighted_average_params(ctrl_surf_latlon,var)
    if 'ALB' in var:
        test_var=test_surf_latlon[var].sel(numurbl=2,numrad=0)
    else:
        test_var=test_surf_latlon[var].sel(numurbl=2)
    ctrl_var=clip_netcdf_by_shp(ctrl_var,us_clusters_geom)
    test_var=clip_netcdf_by_shp(test_var,us_clusters_geom)
    var_mask= (ctrl_var>0) & (test_var>0)
    ctrl_var=ctrl_var.where(var_mask)
    test_var=test_var.where(var_mask)

    ctrl_var=ctrl_var.values.flatten()
    test_var=test_var.values.flatten()
    ctrl_var_clean=ctrl_var[flat_valid_mask]
    test_var_clean=test_var[flat_valid_mask]

    diff_var=test_var_clean-ctrl_var_clean
    diff_var=diff_var[diff_var!=0]
    return diff_var

# %%
diff_em_roof=extract_conus_cluster_ucp_diff('EM_ROOF')
diff_em_improad=extract_conus_cluster_ucp_diff('EM_IMPROAD')
diff_em_perroad=extract_conus_cluster_ucp_diff('EM_PERROAD')
diff_em_wall=extract_conus_cluster_ucp_diff('EM_WALL')

diff_alb_roof=extract_conus_cluster_ucp_diff('ALB_ROOF_DIR')
diff_alb_improad=extract_conus_cluster_ucp_diff('ALB_IMPROAD_DIR')
diff_alb_perroad=extract_conus_cluster_ucp_diff('ALB_PERROAD_DIR')
diff_alb_wall=extract_conus_cluster_ucp_diff('ALB_WALL_DIR')

diff_wt_roof=extract_conus_cluster_ucp_diff('WTLUNIT_ROOF')
diff_wt_perv=extract_conus_cluster_ucp_diff('WTROAD_PERV')
diff_ht_roof=extract_conus_cluster_ucp_diff('HT_ROOF')
diff_hwr=extract_conus_cluster_ucp_diff('CANYON_HWR')

# %%
param_datasets=[diff_em_roof,diff_em_improad,diff_em_perroad,diff_em_wall,
          diff_alb_roof,diff_alb_improad,diff_alb_perroad,diff_alb_wall,
         diff_wt_roof,diff_wt_perv,diff_ht_roof,diff_hwr]

# %%
meteo_vars=['TSKIN_U','TSA_U','RH2M_U','FSH_U','EFLX_LH_TOT_U','FIRA_U','FSA_U','FIRE_U']
meteo_desc_vars=['Land surface T','2m T','2m RH','Sensible heat','Latent heat','Net infrared','Net solar','Upward infrared']
row_names=[rf'$\Delta$ {v}' for v in meteo_desc_vars]

# %%
var_desc = ['Roof $e$', 'Impervious $e$', 'Pervious $e$', 'Wall $e$', 
            'Roof $\\alpha$', 'Impervious $\\alpha$', 'Pervious $\\alpha$', 'Wall $\\alpha$',
            'Roof frac', 'Pervious frac', 'Roof $H$', 'Canyon $H/W$']
xticklabels = [rf'$\Delta$ {v}' for v in var_desc]

# %%
R_list=[]
P_list=[]
for var in meteo_vars:
    R,P=extract_conus_cluster_model_var_diff(var)
    R_list.append(np.asarray(R).reshape(-1))
    P_list.append(np.asarray(P).reshape(-1))

# %%
R = np.asarray(R_list)  # shape (nrow, 12)
P = np.asarray(P_list)  # shape (nrow, 12)

nrow, ncol = R.shape

fig, ax = plt.subplots(figsize=(20, 1.4 * nrow + 1.5))

xx, yy = np.meshgrid(np.arange(ncol), np.arange(nrow))

# bubble size proportional to |r|
smin, smax = 200, 2000
S = smin + (smax - smin) * np.nan_to_num(np.abs(R), nan=0.0)

sc = ax.scatter(
    xx.ravel(), yy.ravel(),
    s=S.ravel(),
    c=R.ravel(),
    cmap="RdYlBu_r",
    vmin=-1, vmax=1,
    edgecolors="k",
    linewidths=0.6
)

# annotate numbers (and significance star)
for i in range(nrow):
    for j in range(ncol):
        r = R[i, j]
        p = P[i, j]
        if np.isfinite(r):
            star = "*" if (np.isfinite(p) and p < 0.05) else ""
            ax.text(j, i, f"{r:+.2f}{star}", ha="center", va="center", fontsize=16)

# formatting
ax.set_xlim(-0.5, ncol - 0.5)
ax.set_ylim(nrow - 0.5, -0.5)  # put first row on top

# y labels for each row
ax.set_yticks(np.arange(nrow))
ax.set_yticklabels(row_names, fontsize=18)

# x labels only on bottom row (set ticks, but hide labels except bottom)
ax.set_xticks(np.arange(ncol))

ax.set_xticklabels(xticklabels, rotation=90, fontsize=18)
ax.tick_params(axis="x", labelbottom=True, bottom=True, top=False)

ax.set_xticks(np.arange(-0.5, ncol, 1), minor=True)
ax.set_yticks(np.arange(-0.5, nrow, 1), minor=True)
ax.grid(which="minor", color="0.85", linewidth=1, linestyle='--')
ax.tick_params(which="minor", bottom=False, left=False)

plt.tight_layout()
fig.savefig('Pearson_r_multi_params_conus_urban_clusters.png', dpi=300, bbox_inches='tight')

# %%
param_datasets
# Out:
# [array([0.07113612, 0.05920827, 0.05773169, ..., 0.0617215 , 0.05757463,
#         0.05860454], shape=(28610,)),
#  array([0.07206587, 0.06044416, 0.05776614, ..., 0.06111943, 0.05734563,
#         0.05766909], shape=(28610,)),
#  array([0.03257638, 0.02097452, 0.01787329, ..., 0.02279794, 0.01794165,
#         0.0206576 ], shape=(28610,)),
#  array([0.06914353, 0.06786567, 0.06689006, ..., 0.06920004, 0.06638217,
#         0.06772763], shape=(28610,)),
#  array([ 0.15431188,  0.16156457,  0.03457904, ...,  0.01299495,
#         -0.01158074,  0.05422951], shape=(28610,)),
#  array([0.10422626, 0.11316884, 0.03360474, ..., 0.00645811, 0.00957968,
#         0.03205122], shape=(28610,)),
#  array([0.09401976, 0.1035566 , 0.07899112, ..., 0.07018809, 0.06772701,
#         0.08062631], shape=(28610,)),
#  array([ 0.23801911,  0.25112873,  0.04546067, ...,  0.0201356 ,
#         -0.01588415,  0.05773208], shape=(28610,)),
#  array([-0.39630806, -0.39498627, -0.36498994, ..., -0.27523057,
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

def build_Xy_from_vectors(y_vec, param_datasets):
    y = np.asarray(y_vec).reshape(-1)

    X_cols = []
    for x in param_datasets:
        x = np.asarray(x).reshape(-1)
        X_cols.append(x)

    X = np.column_stack(X_cols)  # shape (n, 12)

    if X.shape[0] != y.shape[0]:
        raise ValueError(f"Length mismatch: X has {X.shape[0]} rows but y has {y.shape[0]}.")

    m = np.isfinite(y) & np.all(np.isfinite(X), axis=1)
    Xc = X[m, :]
    yc = y[m]
    return Xc, yc, m


def fit_multivar_linear(X, y, standardize=True):
    """
    Fits y ~ X using OLS via sklearn LinearRegression.
    Returns: model, yhat, R2, beta (optionally standardized), intercept, scalers
    """
    if standardize:
        sx = StandardScaler(with_mean=True, with_std=True)
        sy = StandardScaler(with_mean=True, with_std=True)
        Xs = sx.fit_transform(X)
        ys = sy.fit_transform(y.reshape(-1, 1)).ravel()

        model = LinearRegression(fit_intercept=True)
        model.fit(Xs, ys)
        yhat = model.predict(Xs)
        r2 = r2_score(ys, yhat)

        beta = model.coef_.copy()          # standardized coefficients
        intercept = model.intercept_
        return model, yhat, r2, beta, intercept, sx, sy

    model = LinearRegression(fit_intercept=True)
    model.fit(X, y)
    yhat = model.predict(X)
    r2 = r2_score(y, yhat)
    beta = model.coef_.copy()
    intercept = model.intercept_
    return model, yhat, r2, beta, intercept, None, None

def shapley_r2_linear(X, y, n_perm=2000, random_state=0):
    """
    Approximate Shapley R2 (LMG) for a linear model using random permutations.
    Returns: phi (12,), total_R2
    """
    rng = np.random.default_rng(random_state)
    n, p = X.shape
    if p != 12:
        raise ValueError(f"Expected 12 predictors, got {p}.")

    model = LinearRegression(fit_intercept=True)

    # Precompute total R2 for reference
    model.fit(X, y)
    total_r2 = r2_score(y, model.predict(X))

    phi = np.zeros(p, dtype=float)

    for _ in range(n_perm):
        order = rng.permutation(p)

        # Start from intercept-only model: R2 = 0 by definition with sklearn + r2_score using mean baseline
        used = []
        prev_r2 = 0.0

        for j in order:
            used.append(j)
            X_sub = X[:, used]

            model.fit(X_sub, y)
            cur_r2 = r2_score(y, model.predict(X_sub))

            phi[j] += (cur_r2 - prev_r2)
            prev_r2 = cur_r2

    phi /= float(n_perm)

    # Numerical noise can make sum(phi) slightly different from total_r2
    # You can rescale if you want exact additivity:
    if np.isfinite(total_r2) and np.isfinite(phi).all() and phi.sum() != 0:
        phi = phi * (total_r2 / phi.sum())

    return phi, total_r2

# %%
def extract_conus_model_var_diff_multivar(var, param_datasets, standardize=True,
                                          n_perm=2000, random_state=0):
    conus_ctrl = clip_netcdf_by_shp(ctrl_annual_avg_1d32deg[var], us_clusters_geom)
    conus_test = clip_netcdf_by_shp(test_annual_avg_1d32deg[var], us_clusters_geom)

    valid_mask = np.isfinite(conus_ctrl) & np.isfinite(conus_test)
    conus_ctrl = conus_ctrl.where(valid_mask)
    conus_test = conus_test.where(valid_mask)

    ctrl = conus_ctrl.values.flatten()
    test = conus_test.values.flatten()

    flat_valid_mask = np.isfinite(ctrl) & np.isfinite(test)
    ctrl_clean = ctrl[flat_valid_mask]
    test_clean = test[flat_valid_mask]

    y = test_clean - ctrl_clean  # 1D

    # Build X aligned with y. This assumes each element of param_datasets is a 1D vector aligned to y.
    X, y2, m = build_Xy_from_vectors(y, param_datasets)

    # Fit multivariate linear model
    model, yhat, r2, beta, intercept, sx, sy = fit_multivar_linear(X, y2, standardize=standardize)

    # Shapley R2 (variance partition)
    # Important: use the same X used in the fit (standardized X if you standardized for model)
    if standardize:
        X_for_shap = sx.transform(X)
        y_for_shap = sy.transform(y2.reshape(-1, 1)).ravel()
    else:
        X_for_shap = X
        y_for_shap = y2

    phi, total_r2 = shapley_r2_linear(X_for_shap, y_for_shap,
                                      n_perm=n_perm, random_state=random_state)

    return {
        "beta": beta,                 # (12,) standardized if standardize=True
        "intercept": intercept,
        "r2": r2,
        "shapley_r2": phi,            # (12,) sums to total_r2
        "total_r2": total_r2,
        "n": X.shape[0]
    }

# %%
def calculate_residual_energy(ds):
    ds['Residual_U']=ds['FIRA_U']+ds['FSA_U']-ds['EFLX_LH_TOT_U']-ds['FSH_U']
    return ds

# %%
ctrl_annual_avg_1d32deg=calculate_residual_energy(ctrl_annual_avg_1d32deg)
test_annual_avg_1d32deg=calculate_residual_energy(test_annual_avg_1d32deg)

# %%
BETA_list = []
PHI_list = []
R2_list = []
N_list = []

for k, var in enumerate(meteo_vars):
    out = extract_conus_model_var_diff_multivar(
        var,
        param_datasets=param_datasets,
        standardize=True,         # gives comparable beta magnitudes across predictors
        n_perm=3000,              # increase if you want smoother Shapley estimates
        random_state=42 + k)

    BETA_list.append(out["beta"].reshape(-1))          # (12,)
    PHI_list.append(out["shapley_r2"].reshape(-1))     # (12,)
    R2_list.append(out["total_r2"])
    N_list.append(out["n"])

BETA = np.asarray(BETA_list)   # (nrow, 12)
PHI  = np.asarray(PHI_list)    # (nrow, 12)
R2_total = np.asarray(R2_list) # (nrow,)
N_eff = np.asarray(N_list)     # (nrow,)

# %%
meteo_vars=['TSKIN_U','TSA_U','RH2M_U','FSH_U','EFLX_LH_TOT_U','FIRA_U','FSA_U','Residual_U']
meteo_desc_vars=['Land surface T','2m T','2m RH','Sensible heat','Latent heat','Net infrared','Net solar','Residual']
row_names=[rf'$\Delta$ {v}' for v in meteo_desc_vars]

# %%
BETA.shape
# Out:
# (8, 12)

# %%
np.save("multivariate_BETA_5yr_annual.npy", BETA)
np.save("multivariate_PHI_5yr_annual.npy", PHI)
np.save("multivariate_R2_5yr_annual.npy", R2_total)
np.save("multivariate_N_eff_5yr_annual.npy", N_eff)

# %%
BETA=np.load("multivariate_BETA_5yr_annual.npy")
PHI=np.load("multivariate_PHI_5yr_annual.npy")
R2_total=np.load("multivariate_R2_5yr_annual.npy")
N_eff=np.load("multivariate_N_eff_5yr_annual.npy")

# %%
dataset_names=['Roof emissivity', 'Impervious emissivity','Pervious emissivity','Wall emissivity',
              'Roof albedo','Impervious albedo','Pervious albedo','Wall albedo',
              'Roof fraction','Pervious fraction','Building height','Canyon H/W']
var_shortnames=['EM_ROOF','EM_IMPROAD','EM_PERROAD','EM_WALL',
               'ALB_ROOF','ALB_IMPROAD','ALB_PERROAD','ALB_WALL',
               'WTLUNIT_ROOF','WTROAD_PERV','HT_ROOF','CANYON_HWR']

# %%
var_desc = ['Roof $e$', 'Impervious $e$', 'Pervious $e$', 'Wall $e$', 
            'Roof $\\alpha$', 'Impervious $\\alpha$', 'Pervious $\\alpha$', 'Wall $\\alpha$',
            'Roof frac', 'Pervious frac', 'Roof $H$', 'Canyon $H/W$']
xticklabels = [rf'$\Delta$ {v}' for v in var_desc]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm

BETA = np.asarray(BETA)
PHI = np.asarray(PHI)
R2_total = np.asarray(R2_total)
N_eff = np.asarray(N_eff)

nrow, ncol = BETA.shape
assert ncol == 12 and PHI.shape == (nrow, ncol)

# -------------------------
# Plot A: BETA matrix (same grid style)
# -------------------------
figA, axA = plt.subplots(figsize=(12, 1.2 * nrow + 1.6))

vmax = np.nanmax(np.abs(BETA))
if not np.isfinite(vmax) or vmax == 0:
    vmax = 1.0

imA = axA.imshow(
    BETA,
    aspect="auto",
    cmap="RdYlBu_r",
    norm=TwoSlopeNorm(vmin=-vmax, vcenter=0.0, vmax=vmax),
)

# annotate
for i in range(nrow):
    for j in range(ncol):
        val = BETA[i, j]
        if np.isfinite(val):
            axA.text(j, i, f"{val:+.2f}", ha="center", va="center", fontsize=15)

axA.set_xlim(-0.5, ncol - 0.5)
axA.set_ylim(nrow - 0.5, -0.5)

axA.set_yticks(np.arange(nrow))
axA.set_yticklabels(row_names, fontsize=16)

axA.set_xticks(np.arange(ncol))
axA.set_xticklabels(xticklabels, rotation=90, fontsize=16)

axA.set_xticks(np.arange(-0.5, ncol, 1), minor=True)
axA.set_yticks(np.arange(-0.5, nrow, 1), minor=True)
axA.grid(which="minor", color="0.85", linewidth=1, linestyle="--")
axA.tick_params(which="minor", bottom=False, left=False)

cbarA = figA.colorbar(imA, ax=axA, pad=0.02)
# cbarA.set_label("Standardized coefficient (β)", fontsize=15)
cbarA.ax.tick_params(labelsize=16)
axA.set_title("(a) Standardized Coefficient β", fontsize=24)

plt.tight_layout()
figA.savefig(plot_path+"Figure12_revision_multivariate_BETA_5yr_annual.png", dpi=400, bbox_inches="tight")

# %%
# -------------------------
# Plot B: PHI bubble matrix as fraction of total R2 (same bubble style)
# -------------------------
PHI_frac = np.zeros_like(PHI, dtype=float)
m = np.isfinite(R2_total) & (R2_total > 0)
PHI_frac[m, :] = PHI[m, :] / R2_total[m, None]
PHI_frac[~np.isfinite(PHI_frac)] = np.nan

figB, axB = plt.subplots(figsize=(9, 1.2 * nrow + 1.6))

xx, yy = np.meshgrid(np.arange(ncol), np.arange(nrow))

smin, smax = 200, 2000
S = smin + (smax - smin) * np.nan_to_num(PHI_frac, nan=0.0)

scB = axB.scatter(
    xx.ravel(), yy.ravel(),
    s=S.ravel(),
    c=PHI_frac.ravel(),
    cmap="YlGnBu",
    vmin=0.0,
    vmax=np.nanmax(PHI_frac) if np.isfinite(np.nanmax(PHI_frac)) else 1.0,
    edgecolors="k",
    linewidths=0.6,
    alpha=0.7
)

# annotate percent
for i in range(nrow):
    for j in range(ncol):
        val = PHI_frac[i, j]
        if np.isfinite(val):
            axB.text(j, i, f"{100*val:.1f}%", ha="center", va="center", fontsize=15)

axB.set_xlim(-0.5, ncol - 0.5)
axB.set_ylim(nrow - 0.5, -0.5)

axB.set_yticks(np.arange(nrow))
# axB.set_yticklabels(row_names, fontsize=14)
axB.set_yticklabels([])

axB.set_xticks(np.arange(ncol))
axB.set_xticklabels(xticklabels, rotation=90, fontsize=16)

axB.set_xticks(np.arange(-0.5, ncol, 1), minor=True)
axB.set_yticks(np.arange(-0.5, nrow, 1), minor=True)
axB.grid(which="minor", color="0.85", linewidth=1, linestyle="--")
axB.tick_params(which="minor", bottom=False, left=False)

cbarB = figB.colorbar(scB, ax=axB, pad=0.02)
#cbarB.set_label("Shapley share of total $R^2$", fontsize=15)
cbarB.ax.tick_params(labelsize=16)
axB.set_title("(b) Shapley $R^2$ Contribution", fontsize=24)

plt.tight_layout()
figB.savefig(plot_path+"Figure12_revision_multivariate_ShapleyR2_share_5yr_annual.png", dpi=400, bbox_inches="tight")

# %%
# -------------------------
# Plot C: R2_total bar plot (one per meteorology variable)
# -------------------------
figC, axC = plt.subplots(figsize=(6, 1.2 * nrow + 1.6))

ypos = np.arange(nrow)
axC.barh(ypos, R2_total, height=0.75, color='lightgray')

axC.set_ylim(nrow - 0.5, -0.5)
axC.set_yticks(np.arange(nrow))
# axC.set_yticklabels(row_names, fontsize=14)
axC.set_yticklabels([])
axC.set_xlabel("$R^2$", fontsize=17)
axC.tick_params(axis="x", labelsize=16)
# annotate R2 and N_eff
r2max = np.nanmax(R2_total) if np.isfinite(np.nanmax(R2_total)) else 1.0
pad = 0.01 * r2max

for i in range(nrow):
    r2 = R2_total[i]
    n_eff = N_eff[i]
    if np.isfinite(r2):
        txt = f"{r2:.2f}"
        axC.text(r2 + pad, i, txt, va="center", fontsize=18)
axC.set_title("(c) Total $R^2$", fontsize=26)

plt.tight_layout()
figC.savefig(plot_path+"Figure12_revision_multivariate_R2_total_5yr_annual.png", dpi=400, bbox_inches="tight")

# %%
def create_standalone_colorbar(vmin, vmax, cmap='RdYlBu_r', 
                             label=None, label_fontsize=16,
                             tick_values=None, tick_fontsize=16,
                             figsize=(0.35, 10), 
                             orientation='vertical',
                             ticklocation='right',
                             extend='neither'):
    fig = plt.figure(figsize=figsize)
    
    if orientation == 'vertical':
        ax_pos = [0.05, 0.5, 0.9, 0.3]  
    else: 
        ax_pos = [0.5, 0.05, 0.3, 0.9]
    
    ax = fig.add_axes(ax_pos)

    norm = plt.Normalize(vmin=vmin, vmax=vmax)
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    
    cb = plt.colorbar(sm, cax=ax, orientation=orientation, 
                      extend=extend, ticklocation=ticklocation)
    
    cb.outline.set_visible(False)
    
    if tick_values is not None:
        cb.set_ticks(tick_values)
        
    cb.ax.tick_params(labelsize=tick_fontsize, pad=2)
    
    if label:
        cb.set_label(label, fontsize=label_fontsize, labelpad=10, loc='center')
        if orientation == 'vertical' and ticklocation == 'left':
            cb.ax.yaxis.set_label_position('left')
        elif orientation == 'horizontal' and ticklocation == 'top':
            cb.ax.xaxis.set_label_position('top')

    return fig, cb

# %%
fig, cb=create_standalone_colorbar(vmin=-1, vmax=1, cmap='RdYlBu_r', 
                             label='Pearson r', label_fontsize=19,
                             tick_values=[-1.0,-0.5,0.0,0.5,1.0], tick_fontsize=16,
                             figsize=(0.3,15), 
                             orientation='vertical',
                             ticklocation='right',
                             extend='both')
fig.savefig('Pearson_r_colorbar.png', dpi=300, bbox_inches='tight')
